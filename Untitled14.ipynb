# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Untitled spreadsheet - Sheet1 (1).csv')
data
# Out:
#                                                   title price  \
# 0     Babergh and Mid Suffolk District Council Custo...  free
# 1     Babergh and Mid Suffolk District Council Custo...  free
# 2     Babergh and Mid Suffolk District Council Custo...  free
# 3     Babergh and Mid Suffolk District Council Custo...  free
# 4     Babergh and Mid Suffolk District Council Custo...  free
# ...                                                 ...   ...
# 1476   Alexandra Peake Medical Herbalist BSc(Hons) MCPP   NaN
# 1477                              www.planetsuffolk.com   NaN
# 1478                                          Re-engage   NaN
# 1479  Parent & Toddlers Group, The Salvation Army, F...   NaN
# 1480                          Woodbridge Town Youths FC   NaN
#
#      event_start_time             event_start_date  \
# 0                9:00  2023-09-14T00:00:00.000000Z
# 1                9:00  2023-09-18T00:00:00.000000Z
# 2               13:30  2023-09-20T00:00:00.000000Z
# ...

# %%
data['days_and_times']
# test.head()
# Out:
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#                          ...
# 1476                                        NaN
# 1477                                        NaN
# 1478    monthly on sunday from 3.00pm to 5.00pm
# 1479                 mondays 10.00am or 11.30am
# 1480                                        NaN
# Name: days_and_times, Length: 1481, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 83 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   title                                                           1481 non-null   object
#  1   price                                                           577 non-null    object
#  2   event_start_time                                                577 non-null    object
#  3   event_start_date                                                577 non-null    object
#  4   scraped_url                                                     1481 non-null   object
#  5   branch_latitude                                                 576 non-null    float64
#  6   api                                                             1481 non-null   int64
# ...

# %%
sample=data.loc[:,'days_and_times'].fillna("")
sample
# Out:
# 0
# 1
# 2
# 3
# 4
#                          ...
# 1476
# 1477
# 1478    monthly on sunday from 3.00pm to 5.00pm
# 1479                 mondays 10.00am or 11.30am
# 1480
# Name: days_and_times, Length: 1481, dtype: object

# %%
sample1=(data.loc[:,'session_information'].fillna(value=""))
sample1
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1476
# 1477
# 1478
# 1479
# 1480
# Name: session_information, Length: 1481, dtype: object

# %%
timings=pd.concat([sample,sample1],axis=1)
timings
# Out:
#                                days_and_times session_information
# 0
# 1
# 2
# 3
# 4
# ...                                       ...                 ...
# 1476
# 1477
# 1478  monthly on sunday from 3.00pm to 5.00pm
# 1479               mondays 10.00am or 11.30am
# 1480
#
# [1481 rows x 2 columns]
